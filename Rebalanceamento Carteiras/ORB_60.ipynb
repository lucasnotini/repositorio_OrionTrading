# %%
import pandas as pd

# %% [markdown]
# # IMPORTA PLANILHA LONGA E CURTA ORB 60

# %% [markdown]
# ### Coloque o endereço da planilha longa, curta e de ativos dentro das variáveis

# %%
planilha1 = pd.read_excel("ORB 60 IND 0.40 1 ANO.xlsx")
planilha2 = pd.read_excel("ORB 60 IND 0.40 3 MESES.xlsx")
planAtivos = pd.read_excel("ATIVOS.xlsx")

# %%
#cria variaveis de parametros
#pegar nMaiores
nMaiores = 10

# %%
planilha1
# Out:
#     Pass  Result  Profit  Expected Payoff  Profit Factor  Recovery Factor  \
# 0     18   11522    1522        16.543478       1.802743         2.615120
# 1      3   11400    1400        19.444444       1.725765         3.118040
# 2     69   10881     881        10.614458       1.606749         1.678095
# 3     30   10784     784         9.924051       2.302326         4.429379
# 4     78   10711     711         9.608108       1.802483         2.566787
# ..   ...     ...     ...              ...            ...              ...
# 84    27    9274    -726        -6.600000       0.573192        -0.950262
# 85    40    9235    -765        -6.769912       0.547069        -0.858586
# 86    74    9021    -979       -10.414894       0.700337        -0.645778
# 87    37    8932   -1068        -9.798165       0.586207        -0.895222
# 88     5    8891   -1109       -12.322222       0.619945        -0.962674
#
#     Sharpe Ratio  Custom  Equity DD %  Trades  SYMBOL1
# 0       7.897480       0       5.0790      92       18
# 1       7.493457       0       4.2864      72        3
# 2       6.202451       0       4.9617      83       69
# 3       9.702635       0       1.6686      79       30
# 4       8.123958       0       2.7090      74       78
# ..           ...     ...          ...     ...      ...
# 84     -5.000000       0       7.6225     110       27
# 85     -5.000000       0       8.8745     113       40
# 86     -4.164916       0      14.9936      94       74
# 87     -5.000000       0      11.8931     109       37
# 88     -5.000000       0      11.4810      90        5
#
# [89 rows x 11 columns]

# %%
planilha1 = planilha1.sort_values('Pass');
planilha1 = planilha1.set_index('Pass')
planilha1['ATIVOS'] = planAtivos['ATIVO']

planilha1
# Out:
#       Result  Profit  Expected Payoff  Profit Factor  Recovery Factor  \
# Pass
# 0       9588    -412        -4.204082       0.629163        -0.758748
# 1      10500     500         5.681818       1.317058         1.436782
# 2       9750    -250        -3.472222       0.798061        -0.383436
# 3      11400    1400        19.444444       1.725765         3.118040
# 4       9748    -252        -2.470588       0.920455        -0.268657
# ...      ...     ...              ...            ...              ...
# 86     10241     241         3.012500       1.365152         1.275132
# 87     10004       4         0.093023       1.022472         0.041237
# 88      9899    -101        -2.589744       0.768349        -0.326861
# 89     10076      76         1.948718       1.137931         0.304000
# 90     10275     275         7.857143       1.682382         1.462766
#
#       Sharpe Ratio  Custom  Equity DD %  Trades  SYMBOL1 ATIVOS
# Pass
# 0        -5.000000       0       5.4143      98        0  BBDC4
# 1         3.666478       0       3.4286      88        1  ELET3
# 2        -3.407926       0       6.5102      72        2  EZTC3
# 3         7.493457       0       4.2864      72        3  VALE3
# 4        -1.096901       0       8.8876     102        4  RRRP3
# ...            ...     ...          ...     ...      ...    ...
# 86        4.191725       0       1.8562      80       86  USIM5
# 87        0.328072       0       0.9686      43       87  VIIA3
# 88       -3.524709       0       3.0888      39       88  VBBR3
# 89        1.783550       0       2.4640      39       89  WEGE3
# 90        6.456232       0       1.8263      35       90  YDUQ3
#
# [89 rows x 11 columns]

# %%
planilha1 = planilha1[planilha1['Profit Factor'] > 1.1]
planilha1
# Out:
#       Result  Profit  Expected Payoff  Profit Factor  Recovery Factor  \
# Pass
# 1      10500     500         5.681818       1.317058         1.436782
# 3      11400    1400        19.444444       1.725765         3.118040
# 7      10651     651         7.939024       1.246218         0.803704
# 9      10618     618         7.022727       1.314184         1.395034
# 16     10108     108         1.333333       1.139896         0.580645
# 18     11522    1522        16.543478       1.802743         2.615120
# 21     10154     154         1.638298       1.228487         0.880000
# 30     10784     784         9.924051       2.302326         4.429379
# 31     10107     107         1.202247       1.112869         0.426295
# 33     10034      34         0.430380       1.100592         0.320755
# 44     10216     216         2.482759       1.186368         0.760563
# 58     10173     173         2.162500       1.132263         0.519520
# 60     10369     369         4.670886       1.554054         2.617021
# 61     10276     276         3.325301       1.360313         1.633136
# 62     10145     145         2.301587       1.514184         1.169355
# 63     10121     121         1.315217       1.242000         0.883212
# 64     10134     134         1.540230       1.238434         0.641148
# 65     10174     174         1.891304       1.172448         0.621429
# 69     10881     881        10.614458       1.606749         1.678095
# 72     10276     276         3.136364       1.330144         1.408163
# 78     10711     711         9.608108       1.802483         2.566787
# 85     10180     180         2.045455       1.294599         0.878049
# 86     10241     241         3.012500       1.365152         1.275132
# 89     10076      76         1.948718       1.137931         0.304000
# 90     10275     275         7.857143       1.682382         1.462766
#
#       Sharpe Ratio  Custom  Equity DD %  Trades  SYMBOL1 ATIVOS
# Pass
# 1         3.666478       0       3.4286      88        1  ELET3
# 3         7.493457       0       4.2864      72        3  VALE3
# 7         3.378412       0       7.4305      82        7  AMER3
# 9         4.245638       0       4.4238      88        9  AZUL4
# 16        1.528324       0       1.8291      81       16  BRAP4
# 18        7.897480       0       5.0790      92       18  BRKM5
# 21        2.516430       0       1.7003      94       21  CRFB3
# 30        9.702635       0       1.6686      79       30  CVCB3
# 31        1.529543       0       2.4400      89       31  CYRE3
# 33        1.072292       0       1.0499      79       33  ECOR3
# 44        2.590349       0       2.7084      87       44  GOLL4
# 58        1.802126       0       3.3177      80       58  LWSA3
# 60        7.425454       0       1.3691      79       60  MGLU3
# 61        3.793471       0       1.6366      83       61  MRFG3
# 62        5.333234       0       1.2186      63       62  CASH3
# 63        2.662873       0       1.3587      92       63  BEEF3
# 64        2.621865       0       2.0573      87       64  MRVE3
# 65        2.095626       0       2.7349      92       65  MULT3
# 69        6.202451       0       4.9617      83       69  PRIO3
# 72        3.508668       0       1.9274      88       72  QUAL3
# 78        8.123958       0       2.7090      74       78  CSNA3
# 85        3.304761       0       1.9955      88       85  UGPA3
# 86        4.191725       0       1.8562      80       86  USIM5
# 89        1.783550       0       2.4640      39       89  WEGE3
# 90        6.456232       0       1.8263      35       90  YDUQ3

# %%
planilha2 = planilha2.sort_values('Pass')
planilha2 = planilha2.set_index('Pass')
planilha2
# Out:
#       Result  Profit  Expected Payoff  Profit Factor  Recovery Factor  \
# Pass
# 0      10049      49         1.960000       1.235577         0.485149
# 1      10303     303        14.428571       1.851124         1.751445
# 2      10185     185        11.562500       3.500000         2.434211
# 3       9960     -40        -2.666667       0.896641        -0.095694
# 4       9727    -273        -9.413793       0.756250        -0.593478
# ...      ...     ...              ...            ...              ...
# 87     10023      23         1.533333       2.000000         1.095238
# 88     10143     143        14.300000       3.234375         2.134328
# 89      9952     -48        -8.000000       0.472527        -0.436364
# 90     10159     159        14.454545       3.148649         2.484375
# 91     10000       0         0.000000            NaN         0.000000
#
#       Sharpe Ratio  Custom  Equity DD %  Trades  SYMBOL1
# Pass
# 0         3.665541       0       1.0052      25        0
# 1         7.464326       0       1.7049      21        1
# 2         8.194051       0       0.7420      16        2
# 3        -0.400924       0       4.0697      15        3
# 4        -3.931570       0       4.5748      29        4
# ...            ...     ...          ...     ...      ...
# 87        3.737278       0       0.2095      15       87
# 88        4.839698       0       0.6696      10       88
# 89       -0.768571       0       1.0984       6       89
# 90        3.991245       0       0.6298      11       90
# 91        0.000000       0       0.0000       0       91
#
# [91 rows x 10 columns]

# %%
planilha2['FILTRADOS'] = planilha1['ATIVOS']
planilha2
# Out:
#       Result  Profit  Expected Payoff  Profit Factor  Recovery Factor  \
# Pass
# 0      10049      49         1.960000       1.235577         0.485149
# 1      10303     303        14.428571       1.851124         1.751445
# 2      10185     185        11.562500       3.500000         2.434211
# 3       9960     -40        -2.666667       0.896641        -0.095694
# 4       9727    -273        -9.413793       0.756250        -0.593478
# ...      ...     ...              ...            ...              ...
# 87     10023      23         1.533333       2.000000         1.095238
# 88     10143     143        14.300000       3.234375         2.134328
# 89      9952     -48        -8.000000       0.472527        -0.436364
# 90     10159     159        14.454545       3.148649         2.484375
# 91     10000       0         0.000000            NaN         0.000000
#
#       Sharpe Ratio  Custom  Equity DD %  Trades  SYMBOL1 FILTRADOS
# Pass
# 0         3.665541       0       1.0052      25        0       NaN
# 1         7.464326       0       1.7049      21        1     ELET3
# 2         8.194051       0       0.7420      16        2       NaN
# 3        -0.400924       0       4.0697      15        3     VALE3
# 4        -3.931570       0       4.5748      29        4       NaN
# ...            ...     ...          ...     ...      ...       ...
# 87        3.737278       0       0.2095      15       87       NaN
# 88        4.839698       0       0.6696      10       88       NaN
# 89       -0.768571       0       1.0984       6       89     WEGE3
# 90        3.991245       0       0.6298      11       90     YDUQ3
# 91        0.000000       0       0.0000       0       91       NaN
#
# [91 rows x 11 columns]

# %%
planilha2 = planilha2.dropna()
planilha2
# Out:
#       Result  Profit  Expected Payoff  Profit Factor  Recovery Factor  \
# Pass
# 1      10303     303        14.428571       1.851124         1.751445
# 3       9960     -40        -2.666667       0.896641        -0.095694
# 7      10244     244         9.760000       1.544643         0.991870
# 9      10306     306        15.300000       1.894737         1.088968
# 16     10069      69         3.285714       1.343284         0.408284
# 18     10247     247         9.500000       1.730769         1.563291
# 21      9932     -68        -2.833333       0.697778        -0.388571
# 30      9986     -14        -0.777778       0.926316        -0.117647
# 31      9978     -22        -0.880000       0.930818        -0.154930
# 33     10027      27         1.350000       1.500000         0.490909
# 44      9788    -212        -9.217391       0.456410        -0.909871
# 58     10029      29         1.705882       1.216418         0.386667
# 60     10146     146         8.111111       6.840000         6.952381
# 61     10011      11         0.478261       1.049774         0.098214
# 62     10022      22         2.200000       2.222222         1.571429
# 63     10069      69         2.653846       1.413174         0.831325
# 64     10009       9         0.428571       1.054878         0.108434
# 65      9974     -26        -0.962963       0.919505        -0.092857
# 69     10126     126         7.875000       1.409091         0.792453
# 72     10176     176         8.000000       2.060241         1.934066
# 78     10170     170        10.000000       2.465517         1.888889
# 85     10013      13         0.619048       1.090278         0.144444
# 86     10049      49         2.882353       1.628205         0.777778
# 89      9952     -48        -8.000000       0.472527        -0.436364
# 90     10159     159        14.454545       3.148649         2.484375
#
#       Sharpe Ratio  Custom  Equity DD %  Trades  SYMBOL1 FILTRADOS
# Pass
# 1         7.464326       0       1.7049      21        1     ELET3
# 3        -0.400924       0       4.0697      15        3     VALE3
# 7         5.552299       0       2.4210      25        7     AMER3
# 9         9.066985       0       2.7412      20        9     AZUL4
# 16        2.746195       0       1.6701      21       16     BRAP4
# 18        5.685399       0       1.5507      26       18     BRKM5
# 21       -3.421142       0       1.7378      24       21     CRFB3
# 30       -0.652314       0       1.1820      18       30     CVCB3
# 31       -1.380967       0       1.4111      25       31     CYRE3
# 33        3.636960       0       0.5461      20       33     ECOR3
# 44       -5.000000       0       2.3284      23       44     GOLL4
# 58        1.879259       0       0.7481      17       58     LWSA3
# 60       15.754907       0       0.2066      18       60     MGLU3
# 61        0.535754       0       1.1085      23       61     MRFG3
# 62        2.592639       0       0.1396      10       62     CASH3
# 63        3.561278       0       0.8197      26       63     BEEF3
# 64        0.619326       0       0.8274      21       64     MRVE3
# 65       -0.955127       0       2.7894      27       65     MULT3
# 69        3.018032       0       1.5747      16       69     PRIO3
# 72        9.033049       0       0.8992      22       72     QUAL3
# 78        5.990763       0       0.8961      17       78     CSNA3
# 85        0.969822       0       0.8934      21       85     UGPA3
# 86        3.380682       0       0.6278      17       86     USIM5
# 89       -0.768571       0       1.0984       6       89     WEGE3
# 90        3.991245       0       0.6298      11       90     YDUQ3

# %%
planilha2 = planilha2.sort_values('Profit Factor', ascending = False)
planilha2
# Out:
#       Result  Profit  Expected Payoff  Profit Factor  Recovery Factor  \
# Pass
# 60     10146     146         8.111111       6.840000         6.952381
# 90     10159     159        14.454545       3.148649         2.484375
# 78     10170     170        10.000000       2.465517         1.888889
# 62     10022      22         2.200000       2.222222         1.571429
# 72     10176     176         8.000000       2.060241         1.934066
# 9      10306     306        15.300000       1.894737         1.088968
# 1      10303     303        14.428571       1.851124         1.751445
# 18     10247     247         9.500000       1.730769         1.563291
# 86     10049      49         2.882353       1.628205         0.777778
# 7      10244     244         9.760000       1.544643         0.991870
# 33     10027      27         1.350000       1.500000         0.490909
# 63     10069      69         2.653846       1.413174         0.831325
# 69     10126     126         7.875000       1.409091         0.792453
# 16     10069      69         3.285714       1.343284         0.408284
# 58     10029      29         1.705882       1.216418         0.386667
# 85     10013      13         0.619048       1.090278         0.144444
# 64     10009       9         0.428571       1.054878         0.108434
# 61     10011      11         0.478261       1.049774         0.098214
# 31      9978     -22        -0.880000       0.930818        -0.154930
# 30      9986     -14        -0.777778       0.926316        -0.117647
# 65      9974     -26        -0.962963       0.919505        -0.092857
# 3       9960     -40        -2.666667       0.896641        -0.095694
# 21      9932     -68        -2.833333       0.697778        -0.388571
# 89      9952     -48        -8.000000       0.472527        -0.436364
# 44      9788    -212        -9.217391       0.456410        -0.909871
#
#       Sharpe Ratio  Custom  Equity DD %  Trades  SYMBOL1 FILTRADOS
# Pass
# 60       15.754907       0       0.2066      18       60     MGLU3
# 90        3.991245       0       0.6298      11       90     YDUQ3
# 78        5.990763       0       0.8961      17       78     CSNA3
# 62        2.592639       0       0.1396      10       62     CASH3
# 72        9.033049       0       0.8992      22       72     QUAL3
# 9         9.066985       0       2.7412      20        9     AZUL4
# 1         7.464326       0       1.7049      21        1     ELET3
# 18        5.685399       0       1.5507      26       18     BRKM5
# 86        3.380682       0       0.6278      17       86     USIM5
# 7         5.552299       0       2.4210      25        7     AMER3
# 33        3.636960       0       0.5461      20       33     ECOR3
# 63        3.561278       0       0.8197      26       63     BEEF3
# 69        3.018032       0       1.5747      16       69     PRIO3
# 16        2.746195       0       1.6701      21       16     BRAP4
# 58        1.879259       0       0.7481      17       58     LWSA3
# 85        0.969822       0       0.8934      21       85     UGPA3
# 64        0.619326       0       0.8274      21       64     MRVE3
# 61        0.535754       0       1.1085      23       61     MRFG3
# 31       -1.380967       0       1.4111      25       31     CYRE3
# 30       -0.652314       0       1.1820      18       30     CVCB3
# 65       -0.955127       0       2.7894      27       65     MULT3
# 3        -0.400924       0       4.0697      15        3     VALE3
# 21       -3.421142       0       1.7378      24       21     CRFB3
# 89       -0.768571       0       1.0984       6       89     WEGE3
# 44       -5.000000       0       2.3284      23       44     GOLL4

# %%
planilha2.FILTRADOS.head(nMaiores)
# Out:
# Pass
# 60    MGLU3
# 90    YDUQ3
# 78    CSNA3
# 62    CASH3
# 72    QUAL3
# 9     AZUL4
# 1     ELET3
# 18    BRKM5
# 86    USIM5
# 7     AMER3
# Name: FILTRADOS, dtype: object

# %%
#exporta usando método .to_excel
planilha2.to_excel('Relatorio ORB IND 0.40.xlsx')
